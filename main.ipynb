# %%
from ultralytics import YOLO   

# load a pretrained YOLOv8m model
model = YOLO('yolov8m-pose.pt')

# %%
results = model(source="Data/SquatVideo.mp4", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/275) /home/aarons/Projects/Spotter-AI/Data/SquatVideo.mp4: 384x640 3 persons, 186.4ms
# video 1/1 (frame 2/275) /home/aarons/Projects/Spotter-AI/Data/SquatVideo.mp4: 384x640 3 persons, 185.7ms
# video 1/1 (frame 3/275) /home/aarons/Projects/Spotter-AI/Data/SquatVideo.mp4: 384x640 3 persons, 161.1ms
# video 1/1 (frame 4/275) /home/aarons/Projects/Spotter-AI/Data/SquatVideo.mp4: 384x640 3 persons, 77.1ms
# ...
